# %% [markdown]
# <a href="https://colab.research.google.com/github/ExcWasHere/PCVK_2026/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://images.unsplash.com/photo-1514888286974-6c03e2ca1dba?auto=format&fit=crop&w=800&q=80"
]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')

  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image : tingi x lebar =",tinggi," x ",lebar)
  cv2_imshow(image_2)

  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

  #GARIS BOZ
  for y in range (lebar):
    image_3[int((tinggi)/2),y] = [255,255,255]

  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)

# %% [markdown]
# 1. Google Colab digunakan karena memungkinkan kode Python dijalankan langsung melalui browser tanpa harus melakukan instalasi Python dan library secara manual di komputer. Colab juga berbasis cloud sehingga notebook dapat disimpan, dijalankan, dan diintegrasikan dengan Google Drive maupun GitHub.
#
# 2. numpy digunakan untuk manipulasi array, pandas digunakan untuk membuat data frame, cv2 digunakan untuk manipulasi pixel/resize, skimage digunakan untuk membaca image dari URL, pil digunakan untuk membuka image, matplotlib digunakan untuk visualisasi image. tidak semua library harus digunakan
#
# 3. kegunaan nya untuk mengubah ukuran gambar(resize) menjadi lebih kecil, jika kode ini tidak dijalankan maka gambar akan tetap seperti ukuran aslinya sehingga lebih besar ukurannya
#
# 4. menambahkan garis putih dengan kode RGB 255,255,255
#
# 5. resolusi menunjukkan jumlah pixel dalam gambar, sedangkan pixel adalah elemen penyusun gambar. semakin tinggi resolusinya maka semakin banyak juga pixelnya, sebaliknya semakin rendah resolusinya semakin sedikit juga pixelnya sehingga detail gambar semakin rendah

# %%
#Tugas praktikum 2

import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

urls = [
    "https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
    "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
    "https://images.unsplash.com/photo-1514888286974-6c03e2ca1dba?auto=format&fit=crop&w=800&q=80"
]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')

  tinggi = image_2.shape[0]
  lebar = image_2.shape[1]
  print("resolusi image : tingi x lebar =",tinggi," x ",lebar)
  cv2_imshow(image_2)

  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

  #GARIS VERTIKAL BOZ
  for x in range (tinggi):
    image_3[x, int((lebar)/2)] = [255,255,255]

  final_frame = cv.hconcat((image_2, image_3))
  cv2_imshow(final_frame)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Pindahan Dokumen/ktm_exc_scan.jpeg")
plt.imshow(img)

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Pindahan Dokumen/ktm_exc_scan.jpeg")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img_gray = cv2.imread("/content/drive/MyDrive/Pindahan Dokumen/ktm_exc_scan.jpeg", cv2.IMREAD_GRAYSCALE)
#tanpa cmap
plt.subplot(1,2,1)
plt.imshow(img_gray)
plt.title("tanpa cmap")

#with cmap
plt.subplot(1,2,2)
plt.imshow(img_gray, cmap="inferno")
plt.title("with cmap")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

img = cv2.imread("/content/drive/MyDrive/Pindahan Dokumen/ktm_exc_scan.jpeg")
imgRGB=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
imgRGBsmall=cv2.resize(imgRGB, (400,250))
plt.imshow(imgRGBsmall)

imgBalik=cv2.flip(imgRGBsmall,1)
plt.imshow(imgBalik)

# %%
#geo 2d

black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=(10))
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=(15))
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=(8))
cv.circle(black_img,center=(400,400),radius=10,color=(255,0,0),thickness=(100))
cv.line(black_img,pt1=(0,0),pt2=(509,509),color=(255,255,255),thickness=(5))

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img, text="Hello", org=(10,500), fontFace=font, fontScale=4, color=(255,255,0), thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int32)
vertices = np.array([[100,300], [200,200], [400,300], [200,400]],dtype=np.int32)
pts = vertices.reshape((-1,1,2))
cv.polylines(black_img, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# 1. jika menggunakan matplotlib gambar ditampilkan dalam bentuk plot
#
# 2. perbedaannya terletak pada bit dan pengaruhnya adalah int32 menyimpan rentang nilai int lebih besar dripada int 16
#
# 3. agar gambar dapat ditampilkan langsung di google colab
#
# 4. digunakan untuk membaca image dari url
